# %% [markdown]
# # Credit Card Default Risk Prediction\n\nThis notebook runs the same simple pipeline used by `src/train_model.py`: download UCI data, train five ML models, and export CSV files for Excel.

# %%
import sys\nfrom pathlib import Path\n\nPROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.append(str(PROJECT_ROOT / 'src'))\nPROJECT_ROOT

# %%
from train_model import train_and_export\n\ntrain_and_export(force_download=False)

# %%
import pandas as pd\n\nmetrics = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'model_metrics.csv')\nmetrics

# %%
scored = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'credit_default_scored.csv')\nscored[['client_id', 'default_next_month', 'pred_default_prob', 'risk_tier', 'recommended_action']].head()
